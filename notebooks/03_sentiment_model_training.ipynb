# %% [markdown]
# # Module B2: Customer Review Sentiment Model Training
# ## TF-IDF + Logistic Regression / SVM Pipeline
#
# This notebook trains a sentiment classifier to categorize customer reviews into **Positive, Neutral, and Negative** classes with confidence metrics.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

df = pd.read_csv('../data/reviews.csv')
print(f'Reviews dataset size: {len(df)}')
print(df['sentiment'].value_counts())

# %% [markdown]
# ### 1. Build and Train TF-IDF Pipeline

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1, 2), min_df=1, lowercase=True)),
    ('clf', LogisticRegression(max_iter=1000, random_state=42))
])

pipeline.fit(df['text'], df['sentiment'])
preds = pipeline.predict(df['text'])
print(classification_report(df['sentiment'], preds))

# %% [markdown]
# ### 2. Test Sample Inferences

# %%
sample_test = 'Great product! Arrived very fast and quality is supreme.'
pred_label = pipeline.predict([sample_test])[0]
pred_probs = pipeline.predict_proba([sample_test])[0]
print(f'Text: {sample_test}')
print(f'Predicted Sentiment: {pred_label}')
print(f'Confidence Probabilities: {dict(zip(pipeline.classes_, pred_probs))}')
